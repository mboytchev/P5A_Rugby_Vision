# %%
import cv2
import os
from tkinter import Tk, messagebox

video_path="4.mp4"

# %% [markdown]
# ### Accelerer la vidéo

# %%
def accelerate_video(video_path, original_video_speed, factor=4):
    # Ouvrir la vidéo d'entrée
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Erreur : Impossible de lire la vidéo.")
        return

    # Obtenir les propriétés de la vidéo
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    # Nouveau FPS (multiplié par le facteur d'accélération)
    new_fps = fps * factor

    # Configurer l'écrivain de vidéo pour la sortie avec le nouveau FPS
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Format de sortie
    out = cv2.VideoWriter(original_video_speed, fourcc, new_fps, (width, height))

    # Lire et écrire chaque frame à une vitesse plus rapide
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        out.write(frame)

    # Libérer les ressources
    cap.release()
    out.release()
    print(f"Vidéo accélérée sauvegardée sous : {original_video_speed}")

base_name, ext = os.path.splitext(video_path)
original_video_speed = f"{base_name}_speed{ext}"
accelerate_video(video_path, original_video_speed, factor=4)
# Out:
# Vidéo accélérée sauvegardée sous : 4_speed.mp4

# %% [markdown]
# ### Clic quand les penalites sont tirés

# %%
def record_clicks(input_video, output_file):
    # Ouvrir la vidéo
    cap = cv2.VideoCapture(input_video)
    if not cap.isOpened():
        print("Erreur : Impossible de lire la vidéo.")
        return

    clicks = []
    def click_event(event, x, y, flags, param):
        # Si l'utilisateur clique sur la vidéo
        if event == cv2.EVENT_LBUTTONDOWN:
            time = cap.get(cv2.CAP_PROP_POS_MSEC) / 1000  # Temps en secondes
            frame = int(cap.get(cv2.CAP_PROP_POS_FRAMES))  # Numéro de la frame
            clicks.append(f"{time:.2f} seconds, frame {frame}")
            print(f"Clic enregistré à {time:.2f} secondes, frame {frame}")

    # Obtenir les dimensions de la vidéo
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Afficher la vidéo et attendre les clics
    cv2.namedWindow("Accéléré", cv2.WINDOW_NORMAL)
    cv2.resizeWindow("Accéléré", width, height)
    cv2.setMouseCallback("Accéléré", click_event)

    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        cv2.imshow("Accéléré", frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):  # Appuyer sur 'q' pour quitter
            break

    # Sauvegarder les moments des clics dans un fichier texte
    with open(output_file, 'w') as f:
        for click in clicks:
            f.write(click + "\n")

    # Libérer les ressources
    cap.release()
    cv2.destroyAllWindows()
    print(f"Moments des clics sauvegardés dans : {output_file}")

# Utilisation du code
input_video = original_video_speed  # Vidéo accélérée
output_file = "click_times.txt"  # Fichier pour sauvegarder les clics
record_clicks(input_video, output_file)
# Out:
# Clic enregistré à 9.96 secondes, frame 1196
# Clic enregistré à 10.43 secondes, frame 1253
# Clic enregistré à 23.65 secondes, frame 2839
# Clic enregistré à 28.39 secondes, frame 3408
# Moments des clics sauvegardés dans : click_times.txt

# %% [markdown]
# ### Reconstituer la video avec seulement les videos

# %%
def extract_segments(input_video, click_file, final_accelerate_video, padding=1):
    # Ouvrir la vidéo d'entrée
    cap = cv2.VideoCapture(input_video)
    if not cap.isOpened():
        print("Erreur : Impossible de lire la vidéo.")
        return

    # Obtenir les propriétés de la vidéo d'entrée
    fps_input = int(cap.get(cv2.CAP_PROP_FPS))  # FPS d'origine
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    
    # Ouvrir le fichier de sortie avec le FPS original
    out = cv2.VideoWriter(final_accelerate_video, fourcc, fps_input, (width, height))

    # Lire le fichier de clics
    with open(click_file, 'r') as f:
        lines = f.readlines()

    segments = []
    for line in lines:
        time, frame = line.strip().split(', frame ')
        frame_number = int(frame)
        
        # Calcul des frames avant et après le clic, en utilisant la vidéo d'origine
        start_frame = max(0, frame_number - padding * fps_input)  # Prendre 2 sec avant
        end_frame = min(frame_count, frame_number + padding * fps_input)  # Prendre 2 sec après
        segments.append((start_frame, end_frame))

    # Extraire et écrire chaque segment dans la vidéo de sortie
    for start_frame, end_frame in segments:
        cap.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
        for frame_num in range(start_frame, end_frame):
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)

    # Libérer les ressources
    cap.release()
    out.release()
    print(f"Vidéo avec les segments des clics sauvegardée sous : {final_accelerate_video}")

# Utilisation du code
input_video = original_video_speed  # Vidéo d'entrée
click_file = "click_times.txt"  # Fichier des clics
final_accelerate_video = "final_video_accelerate.mp4"  # Vidéo finale
extract_segments(input_video, click_file, final_accelerate_video, padding=1)
# Out:
# Vidéo avec les segments des clics sauvegardée sous : final_video_accelerate.mp4

# %% [markdown]
# ### Decelerer la vidéo avec les penalités

# %%
cap = cv2.VideoCapture('final_video_accelerate.mp4')

fps = cap.get(cv2.CAP_PROP_FPS) 
frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))  

out = cv2.VideoWriter('final_video.mp4', cv2.VideoWriter_fourcc(*'mp4v'), fps / 4, (width, height))

frame_index = 0
while True:
    ret, frame = cap.read()
    if not ret:
        break

    out.write(frame)
    frame_index += 1
    if frame_index % 4 != 0: 
        continue

cap.release()
out.release()
cv2.destroyAllWindows()

# %%
import cv2
import os

def create_segments(video_path, segment_duration=8, segment_folder="segments"):
    """
    Découpe une vidéo en segments d'une durée spécifiée (en secondes).
    :param video_path: Chemin de la vidéo à découper.
    :param segment_duration: Durée de chaque segment en secondes.
    :param segment_folder: Dossier où enregistrer les segments découpés.
    :return: Liste des chemins des segments créés.
    """
    os.makedirs(segment_folder, exist_ok=True)

    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        print("Erreur: Impossible de lire la vidéo.")
        return []

    fps = int(cap.get(cv2.CAP_PROP_FPS))  # Récupérer les FPS de la vidéo
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))  # Récupérer le nombre total de frames
    frames_per_segment = fps * segment_duration  # Durée du segment en nombre de frames
    segment_paths = []

    # Découper la vidéo en segments
    for i in range(0, total_frames, frames_per_segment):
        segment_path = os.path.join(segment_folder, f"segment_{i // frames_per_segment + 1}.mp4")
        segment_paths.append(segment_path)

        # Définir le writer vidéo pour ce segment
        fourcc = cv2.VideoWriter_fourcc(*'mp4v')
        out = cv2.VideoWriter(segment_path, fourcc, fps, 
                              (int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)), int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))))

        cap.set(cv2.CAP_PROP_POS_FRAMES, i)  # Définir la position de départ dans la vidéo
        for _ in range(frames_per_segment):
            ret, frame = cap.read()
            if not ret:
                break
            out.write(frame)

        out.release()

    cap.release()
    print(f"Découpage terminé. {len(segment_paths)} segments créés.")
    return segment_paths

# Exemple d'utilisation :
video_path = 'final_video.mp4'  # Remplacez ce chemin par le chemin de votre vidéo
create_segments(video_path, segment_duration=8)  # Découper la vidéo en segments de 8 secondes
# Out:
# Découpage terminé. 4 segments créés.
# ['segments\\segment_1.mp4',
#  'segments\\segment_2.mp4',
#  'segments\\segment_3.mp4',
#  'segments\\segment_4.mp4']

# %%
import numpy as np

# Fonction pour analyser chaque vidéo
def process_video(video_path, output_path):
    cap = cv2.VideoCapture(video_path)

    if not cap.isOpened():
        print(f"Erreur: Impossible de lire la vidéo {video_path}.")
        return

    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))  # Largeur de la vidéo
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))  # Hauteur de la vidéo
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    print(f"Dimensions de la vidéo {video_path} : {width}x{height}, FPS : {fps}")

    # Initialisation du VideoWriter pour sauvegarder la vidéo annotée
    fourcc = cv2.VideoWriter_fourcc(*'H264')
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_count = 0
    prev_frame = None

    while True:
        ret, frame = cap.read()
        if not ret:
            print(f"Fin de la vidéo {video_path} ou erreur de lecture.")
            break

        gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        if prev_frame is not None:
            diff = cv2.absdiff(prev_frame, gray_frame)
            _, thresh = cv2.threshold(diff, 25, 255, cv2.THRESH_BINARY)

            # Trouver les contours des zones où il y a des différences
            contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

            annotated_frame = frame.copy()
            highest_box = None
            min_y = float('inf')

            # Parcourir les contours et déterminer la boîte avec le plus petit 'y'
            for contour in contours:
                x, y, w, h = cv2.boundingRect(contour)
                if y < min_y:
                    min_y = y
                    highest_box = (x, y, w, h)

            # Si une boîte a été trouvée, dessiner la boîte la plus haute
            if highest_box is not None:
                x, y, w, h = highest_box
                cv2.rectangle(annotated_frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
                cv2.putText(annotated_frame, f"x:{x}, y:{y}", (x, y - 10),
                            cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1)
                print(f"Coordonnées de la boîte la plus haute : x={x}, y={y}, w={w}, h={h}")

            out.write(annotated_frame)

        prev_frame = gray_frame
        frame_count += 1

    cap.release()
    out.release()

    print(f"Vidéo annotée sauvegardée avec succès : {output_path}")

# Analyser toutes les vidéos dans le dossier 'segments/'
segment_folder = 'segments/'
segment_files = [f for f in os.listdir(segment_folder) if f.endswith('.mp4')]

# Créer un dossier pour les vidéos annotées
os.makedirs("segments_annotated", exist_ok=True)

# Traiter chaque vidéo dans le dossier 'segments/'
for segment_file in segment_files:
    video_path = os.path.join(segment_folder, segment_file)
    output_path = os.path.join("segments_annotated", f"annotated_{segment_file}")
    
    # Analyser et annoter la vidéo
    process_video(video_path, output_path)

cv2.destroyAllWindows()
print("Traitement terminé pour toutes les vidéos.")
# Out:
# Dimensions de la vidéo segments/segment_1.mp4 : 1920x1080, FPS : 30
# Coordonnées de la boîte la plus haute : x=1384, y=224, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1876, y=390, w=1, h=1
# Coordonnées de la boîte la plus haute : x=119, y=390, w=1, h=1
# Coordonnées de la boîte la plus haute : x=38, y=382, w=2, h=3
# Coordonnées de la boîte la plus haute : x=399, y=437, w=1, h=1
# Coordonnées de la boîte la plus haute : x=543, y=450, w=6, h=8
# Coordonnées de la boîte la plus haute : x=1914, y=372, w=4, h=1
# Coordonnées de la boîte la plus haute : x=0, y=333, w=9, h=10
# Coordonnées de la boîte la plus haute : x=13, y=317, w=8, h=10
# Coordonnées de la boîte la plus haute : x=1851, y=182, w=1, h=5
# Coordonnées de la boîte la plus haute : x=1634, y=155, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1626, y=150, w=1, h=1
# Coordonnées de la boîte la plus haute : x=64, y=265, w=8, h=7
# Coordonnées de la boîte la plus haute : x=81, y=254, w=3, h=5
# Coordonnées de la boîte la plus haute : x=89, y=243, w=7, h=9
# Coordonnées de la boîte la plus haute : x=100, y=234, w=6, h=6
# Coordonnées de la boîte la plus haute : x=111, y=224, w=9, h=6
# Coordonnées de la boîte la plus haute : x=124, y=216, w=6, h=10
# Coordonnées de la boîte la plus haute : x=134, y=210, w=8, h=8
# Coordonnées de la boîte la plus haute : x=144, y=204, w=7, h=6
# Coordonnées de la boîte la plus haute : x=155, y=196, w=6, h=4
# Coordonnées de la boîte la plus haute : x=166, y=190, w=6, h=6
# Coordonnées de la boîte la plus haute : x=176, y=186, w=4, h=6
# Coordonnées de la boîte la plus haute : x=188, y=182, w=7, h=7
# Coordonnées de la boîte la plus haute : x=196, y=180, w=9, h=5
# Coordonnées de la boîte la plus haute : x=207, y=174, w=3, h=3
# Coordonnées de la boîte la plus haute : x=216, y=171, w=8, h=9
# Coordonnées de la boîte la plus haute : x=1472, y=140, w=2, h=2
# Coordonnées de la boîte la plus haute : x=235, y=168, w=8, h=8
# Coordonnées de la boîte la plus haute : x=245, y=168, w=7, h=6
# Coordonnées de la boîte la plus haute : x=256, y=168, w=6, h=6
# Coordonnées de la boîte la plus haute : x=265, y=168, w=6, h=6
# Coordonnées de la boîte la plus haute : x=264, y=167, w=2, h=2
# Coordonnées de la boîte la plus haute : x=274, y=168, w=5, h=5
# Coordonnées de la boîte la plus haute : x=281, y=169, w=7, h=5
# Coordonnées de la boîte la plus haute : x=290, y=170, w=7, h=6
# Coordonnées de la boîte la plus haute : x=299, y=172, w=7, h=6
# Coordonnées de la boîte la plus haute : x=308, y=173, w=6, h=7
# Coordonnées de la boîte la plus haute : x=316, y=176, w=6, h=7
# Coordonnées de la boîte la plus haute : x=324, y=180, w=6, h=6
# Coordonnées de la boîte la plus haute : x=333, y=184, w=5, h=6
# Coordonnées de la boîte la plus haute : x=341, y=186, w=5, h=8
# Coordonnées de la boîte la plus haute : x=348, y=192, w=6, h=6
# Coordonnées de la boîte la plus haute : x=1717, y=169, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1911, y=191, w=1, h=1
# Coordonnées de la boîte la plus haute : x=372, y=207, w=4, h=6
# Coordonnées de la boîte la plus haute : x=380, y=213, w=4, h=3
# Coordonnées de la boîte la plus haute : x=384, y=218, w=3, h=2
# Coordonnées de la boîte la plus haute : x=393, y=224, w=3, h=1
# Coordonnées de la boîte la plus haute : x=403, y=232, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1785, y=207, w=2, h=1
# Coordonnées de la boîte la plus haute : x=414, y=246, w=5, h=5
# Coordonnées de la boîte la plus haute : x=420, y=252, w=4, h=6
# Coordonnées de la boîte la plus haute : x=1760, y=186, w=1, h=1
# Coordonnées de la boîte la plus haute : x=306, y=228, w=6, h=6
# Coordonnées de la boîte la plus haute : x=303, y=216, w=4, h=6
# Coordonnées de la boîte la plus haute : x=300, y=204, w=2, h=3
# Coordonnées de la boîte la plus haute : x=294, y=192, w=3, h=4
# Coordonnées de la boîte la plus haute : x=288, y=178, w=5, h=6
# Coordonnées de la boîte la plus haute : x=285, y=168, w=3, h=3
# Coordonnées de la boîte la plus haute : x=282, y=156, w=2, h=4
# Coordonnées de la boîte la plus haute : x=276, y=144, w=4, h=5
# Coordonnées de la boîte la plus haute : x=273, y=136, w=3, h=2
# Coordonnées de la boîte la plus haute : x=266, y=123, w=2, h=2
# Coordonnées de la boîte la plus haute : x=447, y=112, w=1, h=1
# Coordonnées de la boîte la plus haute : x=260, y=104, w=2, h=2
# Coordonnées de la boîte la plus haute : x=255, y=96, w=2, h=1
# Coordonnées de la boîte la plus haute : x=253, y=90, w=3, h=2
# Coordonnées de la boîte la plus haute : x=248, y=80, w=1, h=2
# Coordonnées de la boîte la plus haute : x=244, y=73, w=1, h=1
# Coordonnées de la boîte la plus haute : x=243, y=68, w=2, h=2
# Coordonnées de la boîte la plus haute : x=240, y=66, w=2, h=1
# Coordonnées de la boîte la plus haute : x=235, y=54, w=3, h=4
# Coordonnées de la boîte la plus haute : x=230, y=48, w=2, h=1
# Coordonnées de la boîte la plus haute : x=227, y=42, w=2, h=1
# Coordonnées de la boîte la plus haute : x=224, y=37, w=1, h=1
# Coordonnées de la boîte la plus haute : x=222, y=32, w=1, h=1
# Coordonnées de la boîte la plus haute : x=221, y=31, w=3, h=3
# Coordonnées de la boîte la plus haute : x=218, y=26, w=2, h=3
# Coordonnées de la boîte la plus haute : x=218, y=26, w=2, h=3
# Coordonnées de la boîte la plus haute : x=212, y=19, w=3, h=4
# Coordonnées de la boîte la plus haute : x=210, y=17, w=2, h=2
# Coordonnées de la boîte la plus haute : x=207, y=14, w=3, h=2
# Coordonnées de la boîte la plus haute : x=205, y=13, w=2, h=2
# Coordonnées de la boîte la plus haute : x=202, y=11, w=2, h=2
# Coordonnées de la boîte la plus haute : x=200, y=9, w=2, h=3
# Coordonnées de la boîte la plus haute : x=197, y=8, w=2, h=2
# Coordonnées de la boîte la plus haute : x=612, y=240, w=1, h=1
# Coordonnées de la boîte la plus haute : x=464, y=249, w=1, h=1
# Coordonnées de la boîte la plus haute : x=191, y=8, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1598, y=147, w=2, h=1
# Coordonnées de la boîte la plus haute : x=186, y=9, w=1, h=1
# Coordonnées de la boîte la plus haute : x=962, y=336, w=12, h=1
# Coordonnées de la boîte la plus haute : x=551, y=201, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1837, y=216, w=3, h=1
# Coordonnées de la boîte la plus haute : x=572, y=244, w=1, h=1
# Coordonnées de la boîte la plus haute : x=149, y=400, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1617, y=179, w=1, h=1
# Coordonnées de la boîte la plus haute : x=172, y=27, w=1, h=1
# Coordonnées de la boîte la plus haute : x=172, y=27, w=2, h=1
# Coordonnées de la boîte la plus haute : x=146, y=400, w=1, h=1
# Coordonnées de la boîte la plus haute : x=168, y=33, w=1, h=1
# Coordonnées de la boîte la plus haute : x=162, y=40, w=2, h=1
# Coordonnées de la boîte la plus haute : x=162, y=40, w=2, h=1
# Coordonnées de la boîte la plus haute : x=51, y=384, w=1, h=3
# Coordonnées de la boîte la plus haute : x=132, y=402, w=1, h=5
# Coordonnées de la boîte la plus haute : x=159, y=58, w=1, h=1
# Coordonnées de la boîte la plus haute : x=878, y=389, w=7, h=7
# Coordonnées de la boîte la plus haute : x=880, y=373, w=8, h=13
# Coordonnées de la boîte la plus haute : x=154, y=83, w=2, h=2
# Coordonnées de la boîte la plus haute : x=154, y=83, w=2, h=2
# Coordonnées de la boîte la plus haute : x=152, y=90, w=2, h=2
# Coordonnées de la boîte la plus haute : x=149, y=105, w=3, h=2
# Coordonnées de la boîte la plus haute : x=1059, y=199, w=1, h=1
# Coordonnées de la boîte la plus haute : x=146, y=120, w=3, h=2
# Coordonnées de la boîte la plus haute : x=893, y=286, w=13, h=23
# Coordonnées de la boîte la plus haute : x=144, y=136, w=3, h=4
# Coordonnées de la boîte la plus haute : x=144, y=137, w=3, h=3
# Coordonnées de la boîte la plus haute : x=143, y=145, w=3, h=4
# Coordonnées de la boîte la plus haute : x=140, y=154, w=2, h=1
# Coordonnées de la boîte la plus haute : x=142, y=163, w=2, h=4
# Coordonnées de la boîte la plus haute : x=138, y=180, w=3, h=4
# Coordonnées de la boîte la plus haute : x=139, y=181, w=2, h=3
# Coordonnées de la boîte la plus haute : x=138, y=193, w=3, h=4
# Coordonnées de la boîte la plus haute : x=897, y=186, w=15, h=26
# Coordonnées de la boîte la plus haute : x=897, y=177, w=14, h=23
# Coordonnées de la boîte la plus haute : x=998, y=144, w=1, h=1
# Coordonnées de la boîte la plus haute : x=900, y=160, w=3, h=3
# Coordonnées de la boîte la plus haute : x=893, y=152, w=16, h=22
# Coordonnées de la boîte la plus haute : x=890, y=142, w=2, h=2
# Coordonnées de la boîte la plus haute : x=886, y=136, w=19, h=25
# Coordonnées de la boîte la plus haute : x=885, y=132, w=17, h=21
# Coordonnées de la boîte la plus haute : x=885, y=124, w=6, h=6
# Coordonnées de la boîte la plus haute : x=883, y=121, w=5, h=4
# Coordonnées de la boîte la plus haute : x=873, y=119, w=20, h=20
# Coordonnées de la boîte la plus haute : x=866, y=112, w=16, h=17
# Coordonnées de la boîte la plus haute : x=861, y=112, w=25, h=23
# Coordonnées de la boîte la plus haute : x=857, y=112, w=23, h=21
# Coordonnées de la boîte la plus haute : x=849, y=112, w=26, h=24
# Coordonnées de la boîte la plus haute : x=844, y=112, w=28, h=25
# Coordonnées de la boîte la plus haute : x=836, y=116, w=28, h=26
# Coordonnées de la boîte la plus haute : x=825, y=120, w=32, h=29
# Coordonnées de la boîte la plus haute : x=818, y=122, w=33, h=32
# Coordonnées de la boîte la plus haute : x=809, y=132, w=31, h=35
# Coordonnées de la boîte la plus haute : x=796, y=140, w=36, h=41
# Coordonnées de la boîte la plus haute : x=789, y=150, w=36, h=43
# Coordonnées de la boîte la plus haute : x=655, y=155, w=1, h=1
# Coordonnées de la boîte la plus haute : x=758, y=183, w=44, h=48
# Coordonnées de la boîte la plus haute : x=1523, y=191, w=2, h=1
# Coordonnées de la boîte la plus haute : x=744, y=226, w=29, h=26
# Coordonnées de la boîte la plus haute : x=727, y=251, w=33, h=36
# Coordonnées de la boîte la plus haute : x=1760, y=198, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1704, y=204, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1700, y=201, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1791, y=184, w=1, h=1
# Coordonnées de la boîte la plus haute : x=874, y=195, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1002, y=62, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1118, y=208, w=2, h=1
# Coordonnées de la boîte la plus haute : x=16, y=264, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1200, y=276, w=10, h=13
# Coordonnées de la boîte la plus haute : x=1188, y=258, w=11, h=11
# Coordonnées de la boîte la plus haute : x=1919, y=190, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1176, y=222, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1759, y=192, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1146, y=176, w=7, h=12
# Coordonnées de la boîte la plus haute : x=1135, y=157, w=9, h=11
# Coordonnées de la boîte la plus haute : x=1122, y=135, w=10, h=16
# Coordonnées de la boîte la plus haute : x=1107, y=116, w=13, h=15
# Coordonnées de la boîte la plus haute : x=1094, y=97, w=11, h=13
# Coordonnées de la boîte la plus haute : x=1086, y=73, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1062, y=55, w=14, h=13
# Coordonnées de la boîte la plus haute : x=1048, y=33, w=6, h=7
# Coordonnées de la boîte la plus haute : x=1031, y=12, w=10, h=13
# Coordonnées de la boîte la plus haute : x=1015, y=0, w=11, h=8
# Coordonnées de la boîte la plus haute : x=1015, y=0, w=11, h=8
# Coordonnées de la boîte la plus haute : x=1763, y=135, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1002, y=80, w=2, h=5
# Coordonnées de la boîte la plus haute : x=1003, y=97, w=1, h=5
# Coordonnées de la boîte la plus haute : x=1487, y=189, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1775, y=189, w=1, h=1
# Coordonnées de la boîte la plus haute : x=458, y=131, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1374, y=227, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1166, y=192, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1430, y=190, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1518, y=207, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1851, y=184, w=1, h=6
# Coordonnées de la boîte la plus haute : x=1761, y=207, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1787, y=173, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1907, y=160, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1700, y=202, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1535, y=242, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1584, y=243, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1002, y=48, w=1, h=8
# Coordonnées de la boîte la plus haute : x=447, y=184, w=1, h=2
# Coordonnées de la boîte la plus haute : x=512, y=231, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1171, y=192, w=3, h=1
# Coordonnées de la boîte la plus haute : x=399, y=240, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1168, y=135, w=1, h=1
# Coordonnées de la boîte la plus haute : x=360, y=185, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1499, y=200, w=2, h=1
# Fin de la vidéo segments/segment_1.mp4 ou erreur de lecture.
# Vidéo annotée sauvegardée avec succès : segments_annotated\annotated_segment_1.mp4
# Dimensions de la vidéo segments/segment_2.mp4 : 1920x1080, FPS : 30
# Coordonnées de la boîte la plus haute : x=393, y=224, w=3, h=1
# Coordonnées de la boîte la plus haute : x=403, y=232, w=2, h=2
# Coordonnées de la boîte la plus haute : x=408, y=237, w=5, h=8
# Coordonnées de la boîte la plus haute : x=414, y=246, w=5, h=5
# Coordonnées de la boîte la plus haute : x=420, y=252, w=4, h=6
# Coordonnées de la boîte la plus haute : x=311, y=243, w=5, h=4
# Coordonnées de la boîte la plus haute : x=1618, y=140, w=1, h=1
# Coordonnées de la boîte la plus haute : x=303, y=216, w=4, h=6
# Coordonnées de la boîte la plus haute : x=300, y=204, w=2, h=3
# Coordonnées de la boîte la plus haute : x=294, y=192, w=3, h=4
# Coordonnées de la boîte la plus haute : x=288, y=178, w=5, h=6
# Coordonnées de la boîte la plus haute : x=285, y=168, w=3, h=3
# Coordonnées de la boîte la plus haute : x=282, y=156, w=2, h=3
# Coordonnées de la boîte la plus haute : x=276, y=144, w=4, h=5
# Coordonnées de la boîte la plus haute : x=273, y=136, w=3, h=2
# Coordonnées de la boîte la plus haute : x=266, y=123, w=2, h=2
# Coordonnées de la boîte la plus haute : x=447, y=112, w=1, h=1
# Coordonnées de la boîte la plus haute : x=260, y=104, w=2, h=2
# Coordonnées de la boîte la plus haute : x=255, y=96, w=2, h=1
# Coordonnées de la boîte la plus haute : x=253, y=90, w=3, h=2
# Coordonnées de la boîte la plus haute : x=253, y=90, w=3, h=2
# Coordonnées de la boîte la plus haute : x=244, y=73, w=1, h=1
# Coordonnées de la boîte la plus haute : x=243, y=68, w=2, h=2
# Coordonnées de la boîte la plus haute : x=240, y=66, w=1, h=1
# Coordonnées de la boîte la plus haute : x=235, y=54, w=3, h=4
# Coordonnées de la boîte la plus haute : x=230, y=48, w=2, h=1
# Coordonnées de la boîte la plus haute : x=228, y=42, w=1, h=1
# Coordonnées de la boîte la plus haute : x=226, y=39, w=3, h=5
# Coordonnées de la boîte la plus haute : x=224, y=35, w=2, h=5
# Coordonnées de la boîte la plus haute : x=221, y=30, w=2, h=4
# Coordonnées de la boîte la plus haute : x=217, y=26, w=3, h=3
# Coordonnées de la boîte la plus haute : x=218, y=26, w=2, h=2
# Coordonnées de la boîte la plus haute : x=212, y=20, w=3, h=3
# Coordonnées de la boîte la plus haute : x=210, y=18, w=1, h=2
# Coordonnées de la boîte la plus haute : x=207, y=14, w=2, h=2
# Coordonnées de la boîte la plus haute : x=205, y=13, w=1, h=2
# Coordonnées de la boîte la plus haute : x=202, y=11, w=2, h=2
# Coordonnées de la boîte la plus haute : x=200, y=10, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1488, y=72, w=2, h=1
# Coordonnées de la boîte la plus haute : x=614, y=253, w=2, h=1
# Coordonnées de la boîte la plus haute : x=192, y=8, w=1, h=1
# Coordonnées de la boîte la plus haute : x=190, y=8, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1599, y=147, w=1, h=1
# Coordonnées de la boîte la plus haute : x=186, y=9, w=1, h=2
# Coordonnées de la boîte la plus haute : x=962, y=336, w=13, h=1
# Coordonnées de la boîte la plus haute : x=551, y=201, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1736, y=203, w=1, h=1
# Coordonnées de la boîte la plus haute : x=574, y=244, w=1, h=1
# Coordonnées de la boîte la plus haute : x=83, y=378, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1432, y=211, w=1, h=1
# Coordonnées de la boîte la plus haute : x=172, y=27, w=1, h=1
# Coordonnées de la boîte la plus haute : x=172, y=27, w=1, h=1
# Coordonnées de la boîte la plus haute : x=154, y=401, w=2, h=2
# Coordonnées de la boîte la plus haute : x=168, y=33, w=1, h=2
# Coordonnées de la boîte la plus haute : x=167, y=39, w=1, h=1
# Coordonnées de la boîte la plus haute : x=48, y=336, w=2, h=1
# Coordonnées de la boîte la plus haute : x=51, y=384, w=2, h=3
# Coordonnées de la boîte la plus haute : x=132, y=402, w=1, h=4
# Coordonnées de la boîte la plus haute : x=98, y=381, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1815, y=197, w=1, h=1
# Coordonnées de la boîte la plus haute : x=880, y=373, w=8, h=13
# Coordonnées de la boîte la plus haute : x=154, y=83, w=2, h=2
# Coordonnées de la boîte la plus haute : x=154, y=83, w=2, h=2
# Coordonnées de la boîte la plus haute : x=153, y=90, w=1, h=2
# Coordonnées de la boîte la plus haute : x=149, y=105, w=3, h=2
# Coordonnées de la boîte la plus haute : x=676, y=163, w=1, h=1
# Coordonnées de la boîte la plus haute : x=146, y=120, w=3, h=2
# Coordonnées de la boîte la plus haute : x=893, y=286, w=12, h=23
# Coordonnées de la boîte la plus haute : x=144, y=137, w=3, h=3
# Coordonnées de la boîte la plus haute : x=144, y=137, w=3, h=3
# Coordonnées de la boîte la plus haute : x=144, y=145, w=2, h=4
# Coordonnées de la boîte la plus haute : x=140, y=154, w=2, h=1
# Coordonnées de la boîte la plus haute : x=141, y=163, w=3, h=5
# Coordonnées de la boîte la plus haute : x=138, y=180, w=3, h=4
# Coordonnées de la boîte la plus haute : x=138, y=181, w=3, h=3
# Coordonnées de la boîte la plus haute : x=138, y=193, w=3, h=4
# Coordonnées de la boîte la plus haute : x=897, y=186, w=15, h=26
# Coordonnées de la boîte la plus haute : x=897, y=177, w=14, h=23
# Coordonnées de la boîte la plus haute : x=895, y=167, w=3, h=2
# Coordonnées de la boîte la plus haute : x=900, y=160, w=4, h=3
# Coordonnées de la boîte la plus haute : x=893, y=152, w=16, h=22
# Coordonnées de la boîte la plus haute : x=890, y=142, w=2, h=3
# Coordonnées de la boîte la plus haute : x=886, y=137, w=19, h=24
# Coordonnées de la boîte la plus haute : x=885, y=132, w=17, h=21
# Coordonnées de la boîte la plus haute : x=884, y=124, w=7, h=5
# Coordonnées de la boîte la plus haute : x=882, y=121, w=6, h=4
# Coordonnées de la boîte la plus haute : x=874, y=119, w=20, h=20
# Coordonnées de la boîte la plus haute : x=866, y=112, w=23, h=24
# Coordonnées de la boîte la plus haute : x=871, y=112, w=1, h=1
# Coordonnées de la boîte la plus haute : x=857, y=112, w=23, h=21
# Coordonnées de la boîte la plus haute : x=849, y=112, w=26, h=25
# Coordonnées de la boîte la plus haute : x=844, y=112, w=28, h=25
# Coordonnées de la boîte la plus haute : x=836, y=116, w=28, h=26
# Coordonnées de la boîte la plus haute : x=825, y=120, w=32, h=29
# Coordonnées de la boîte la plus haute : x=818, y=122, w=33, h=32
# Coordonnées de la boîte la plus haute : x=809, y=132, w=31, h=35
# Coordonnées de la boîte la plus haute : x=796, y=140, w=36, h=41
# Coordonnées de la boîte la plus haute : x=789, y=150, w=36, h=43
# Coordonnées de la boîte la plus haute : x=654, y=155, w=2, h=1
# Coordonnées de la boîte la plus haute : x=758, y=183, w=44, h=48
# Coordonnées de la boîte la plus haute : x=1523, y=191, w=2, h=1
# Coordonnées de la boîte la plus haute : x=745, y=226, w=28, h=27
# Coordonnées de la boîte la plus haute : x=727, y=251, w=33, h=36
# Coordonnées de la boîte la plus haute : x=1760, y=198, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1141, y=218, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1760, y=198, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1254, y=196, w=1, h=1
# Coordonnées de la boîte la plus haute : x=874, y=195, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1184, y=282, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1786, y=184, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1653, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1200, y=276, w=10, h=14
# Coordonnées de la boîte la plus haute : x=1189, y=258, w=10, h=11
# Coordonnées de la boîte la plus haute : x=1919, y=190, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1176, y=222, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1254, y=199, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1146, y=176, w=7, h=12
# Coordonnées de la boîte la plus haute : x=1135, y=157, w=9, h=11
# Coordonnées de la boîte la plus haute : x=1122, y=135, w=10, h=16
# Coordonnées de la boîte la plus haute : x=1107, y=116, w=13, h=15
# Coordonnées de la boîte la plus haute : x=1094, y=97, w=11, h=13
# Coordonnées de la boîte la plus haute : x=1086, y=73, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1062, y=55, w=14, h=13
# Coordonnées de la boîte la plus haute : x=1048, y=33, w=6, h=7
# Coordonnées de la boîte la plus haute : x=1031, y=12, w=10, h=13
# Coordonnées de la boîte la plus haute : x=1015, y=0, w=11, h=8
# Coordonnées de la boîte la plus haute : x=1015, y=0, w=11, h=8
# Coordonnées de la boîte la plus haute : x=486, y=119, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1488, y=74, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=140, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1487, y=189, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1775, y=189, w=1, h=1
# Coordonnées de la boîte la plus haute : x=458, y=131, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1740, y=200, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1539, y=198, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1605, y=144, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1578, y=217, w=4, h=2
# Coordonnées de la boîte la plus haute : x=1851, y=184, w=1, h=7
# Coordonnées de la boîte la plus haute : x=1767, y=288, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1787, y=172, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1364, y=139, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1103, y=191, w=1, h=1
# Coordonnées de la boîte la plus haute : x=146, y=406, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1584, y=243, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1363, y=139, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1499, y=146, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1919, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1172, y=192, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1593, y=239, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1316, y=98, w=1, h=1
# Coordonnées de la boîte la plus haute : x=360, y=184, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1499, y=200, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1499, y=200, w=2, h=1
# Coordonnées de la boîte la plus haute : x=467, y=115, w=1, h=1
# Coordonnées de la boîte la plus haute : x=948, y=326, w=1, h=10
# Coordonnées de la boîte la plus haute : x=1630, y=156, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1784, y=174, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1768, y=195, w=1, h=1
# Coordonnées de la boîte la plus haute : x=424, y=282, w=8, h=1
# Coordonnées de la boîte la plus haute : x=856, y=216, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1323, y=113, w=2, h=1
# Coordonnées de la boîte la plus haute : x=863, y=161, w=1, h=1
# Coordonnées de la boîte la plus haute : x=613, y=227, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1692, y=229, w=1, h=1
# Coordonnées de la boîte la plus haute : x=663, y=225, w=1, h=1
# Coordonnées de la boîte la plus haute : x=706, y=164, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=140, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1880, y=219, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1447, y=224, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1650, y=152, w=1, h=1
# Coordonnées de la boîte la plus haute : x=707, y=164, w=2, h=1
# Coordonnées de la boîte la plus haute : x=159, y=410, w=7, h=13
# Coordonnées de la boîte la plus haute : x=595, y=372, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1701, y=197, w=2, h=3
# Coordonnées de la boîte la plus haute : x=1154, y=192, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1098, y=199, w=2, h=1
# Coordonnées de la boîte la plus haute : x=163, y=409, w=5, h=3
# Coordonnées de la boîte la plus haute : x=1264, y=260, w=2, h=1
# Coordonnées de la boîte la plus haute : x=675, y=251, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1776, y=254, w=1, h=1
# Coordonnées de la boîte la plus haute : x=170, y=419, w=2, h=4
# Coordonnées de la boîte la plus haute : x=1559, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=115, y=416, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1619, y=264, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1623, y=255, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1799, y=230, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1485, y=72, w=1, h=1
# Coordonnées de la boîte la plus haute : x=460, y=47, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1002, y=38, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1485, y=72, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1763, y=135, w=1, h=4
# Coordonnées de la boîte la plus haute : x=1382, y=191, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1114, y=191, w=1, h=1
# Coordonnées de la boîte la plus haute : x=459, y=48, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1003, y=38, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1004, y=178, w=1, h=1
# Coordonnées de la boîte la plus haute : x=486, y=120, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1063, y=141, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1671, y=127, w=2, h=1
# Fin de la vidéo segments/segment_2.mp4 ou erreur de lecture.
# Vidéo annotée sauvegardée avec succès : segments_annotated\annotated_segment_2.mp4
# Dimensions de la vidéo segments/segment_3.mp4 : 1920x1080, FPS : 30
# Coordonnées de la boîte la plus haute : x=1504, y=80, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1791, y=383, w=1, h=1
# Coordonnées de la boîte la plus haute : x=160, y=390, w=2, h=4
# Coordonnées de la boîte la plus haute : x=158, y=409, w=2, h=3
# Coordonnées de la boîte la plus haute : x=1608, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1314, y=144, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=142, w=1, h=2
# Coordonnées de la boîte la plus haute : x=160, y=388, w=3, h=6
# Coordonnées de la boîte la plus haute : x=148, y=386, w=4, h=3
# Coordonnées de la boîte la plus haute : x=1647, y=219, w=1, h=1
# Coordonnées de la boîte la plus haute : x=168, y=389, w=1, h=5
# Coordonnées de la boîte la plus haute : x=1826, y=295, w=2, h=1
# Coordonnées de la boîte la plus haute : x=490, y=231, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1748, y=239, w=2, h=2
# Coordonnées de la boîte la plus haute : x=630, y=278, w=4, h=1
# Coordonnées de la boîte la plus haute : x=1595, y=312, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1623, y=256, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1508, y=144, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1653, y=214, w=2, h=2
# Coordonnées de la boîte la plus haute : x=464, y=281, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1581, y=234, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=143, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1509, y=214, w=1, h=2
# Coordonnées de la boîte la plus haute : x=457, y=40, w=1, h=1
# Coordonnées de la boîte la plus haute : x=177, y=386, w=4, h=13
# Coordonnées de la boîte la plus haute : x=1650, y=224, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1642, y=234, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1696, y=296, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1620, y=262, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1579, y=234, w=1, h=1
# Coordonnées de la boîte la plus haute : x=551, y=229, w=3, h=1
# Coordonnées de la boîte la plus haute : x=706, y=161, w=1, h=1
# Coordonnées de la boîte la plus haute : x=514, y=257, w=7, h=1
# Coordonnées de la boîte la plus haute : x=1848, y=195, w=1, h=2
# Coordonnées de la boîte la plus haute : x=519, y=258, w=1, h=1
# Coordonnées de la boîte la plus haute : x=702, y=156, w=2, h=1
# Coordonnées de la boîte la plus haute : x=184, y=386, w=2, h=4
# Coordonnées de la boîte la plus haute : x=478, y=232, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1557, y=287, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1476, y=243, w=2, h=2
# Coordonnées de la boîte la plus haute : x=187, y=385, w=2, h=3
# Coordonnées de la boîte la plus haute : x=604, y=238, w=2, h=3
# Coordonnées de la boîte la plus haute : x=608, y=237, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1582, y=223, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1509, y=223, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1642, y=235, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1704, y=275, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1512, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=726, y=167, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1058, y=200, w=1, h=1
# Coordonnées de la boîte la plus haute : x=734, y=275, w=5, h=1
# Coordonnées de la boîte la plus haute : x=1059, y=200, w=1, h=1
# Coordonnées de la boîte la plus haute : x=730, y=213, w=2, h=2
# Coordonnées de la boîte la plus haute : x=576, y=228, w=3, h=2
# Coordonnées de la boîte la plus haute : x=1696, y=237, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1704, y=268, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1559, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=202, y=392, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1690, y=240, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1634, y=279, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1693, y=237, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1556, y=303, w=1, h=1
# Coordonnées de la boîte la plus haute : x=446, y=187, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1902, y=201, w=1, h=2
# Coordonnées de la boîte la plus haute : x=605, y=240, w=3, h=1
# Coordonnées de la boîte la plus haute : x=553, y=229, w=1, h=1
# Coordonnées de la boîte la plus haute : x=479, y=431, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=142, w=1, h=2
# Coordonnées de la boîte la plus haute : x=445, y=184, w=2, h=3
# Coordonnées de la boîte la plus haute : x=1439, y=339, w=17, h=2
# Coordonnées de la boîte la plus haute : x=1700, y=464, w=12, h=10
# Coordonnées de la boîte la plus haute : x=208, y=387, w=2, h=5
# Coordonnées de la boîte la plus haute : x=1710, y=264, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1709, y=289, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1712, y=265, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1704, y=276, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1711, y=274, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1831, y=296, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1755, y=202, w=1, h=1
# Coordonnées de la boîte la plus haute : x=602, y=239, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1802, y=296, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1559, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1540, y=312, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1703, y=244, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1580, y=256, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1672, y=468, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1552, y=312, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1765, y=183, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1538, y=263, w=1, h=1
# Coordonnées de la boîte la plus haute : x=162, y=416, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1447, y=224, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1905, y=240, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1512, y=212, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1803, y=296, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1556, y=223, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1651, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1648, y=222, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1904, y=239, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1623, y=255, w=1, h=1
# Coordonnées de la boîte la plus haute : x=162, y=395, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1538, y=261, w=1, h=1
# Coordonnées de la boîte la plus haute : x=160, y=415, w=2, h=1
# Coordonnées de la boîte la plus haute : x=597, y=242, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1557, y=215, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1695, y=216, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1907, y=159, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1608, y=214, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1560, y=354, w=4, h=6
# Coordonnées de la boîte la plus haute : x=1619, y=266, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1712, y=207, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1712, y=240, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1727, y=200, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1618, y=264, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1768, y=201, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1655, y=213, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1727, y=190, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1524, y=203, w=2, h=2
# Coordonnées de la boîte la plus haute : x=360, y=184, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1512, y=170, w=9, h=10
# Coordonnées de la boîte la plus haute : x=1507, y=156, w=10, h=7
# Coordonnées de la boîte la plus haute : x=1504, y=137, w=5, h=6
# Coordonnées de la boîte la plus haute : x=1499, y=120, w=9, h=10
# Coordonnées de la boîte la plus haute : x=1496, y=104, w=7, h=11
# Coordonnées de la boîte la plus haute : x=1488, y=87, w=10, h=13
# Coordonnées de la boîte la plus haute : x=1485, y=72, w=8, h=10
# Coordonnées de la boîte la plus haute : x=1479, y=56, w=10, h=13
# Coordonnées de la boîte la plus haute : x=1476, y=42, w=6, h=3
# Coordonnées de la boîte la plus haute : x=1470, y=28, w=6, h=6
# Coordonnées de la boîte la plus haute : x=1464, y=12, w=8, h=8
# Coordonnées de la boîte la plus haute : x=1458, y=0, w=11, h=9
# Coordonnées de la boîte la plus haute : x=1458, y=0, w=11, h=9
# Coordonnées de la boîte la plus haute : x=488, y=182, w=1, h=2
# Coordonnées de la boîte la plus haute : x=480, y=176, w=1, h=1
# Coordonnées de la boîte la plus haute : x=474, y=168, w=2, h=2
# Coordonnées de la boîte la plus haute : x=474, y=168, w=1, h=1
# Coordonnées de la boîte la plus haute : x=457, y=154, w=1, h=1
# Coordonnées de la boîte la plus haute : x=451, y=147, w=2, h=3
# Coordonnées de la boîte la plus haute : x=446, y=142, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1559, y=287, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1469, y=206, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1651, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1578, y=223, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1509, y=213, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1559, y=303, w=1, h=1
# Coordonnées de la boîte la plus haute : x=402, y=117, w=3, h=3
# Coordonnées de la boîte la plus haute : x=397, y=115, w=3, h=3
# Coordonnées de la boîte la plus haute : x=390, y=112, w=3, h=3
# Coordonnées de la boîte la plus haute : x=384, y=109, w=1, h=3
# Coordonnées de la boîte la plus haute : x=379, y=108, w=3, h=4
# Coordonnées de la boîte la plus haute : x=379, y=109, w=3, h=3
# Coordonnées de la boîte la plus haute : x=368, y=106, w=1, h=1
# Coordonnées de la boîte la plus haute : x=362, y=106, w=1, h=1
# Coordonnées de la boîte la plus haute : x=357, y=105, w=3, h=5
# Coordonnées de la boîte la plus haute : x=358, y=105, w=2, h=6
# Coordonnées de la boîte la plus haute : x=348, y=108, w=2, h=4
# Coordonnées de la boîte la plus haute : x=348, y=108, w=2, h=4
# Coordonnées de la boîte la plus haute : x=337, y=109, w=3, h=5
# Coordonnées de la boîte la plus haute : x=337, y=109, w=3, h=5
# Coordonnées de la boîte la plus haute : x=329, y=115, w=1, h=2
# Coordonnées de la boîte la plus haute : x=329, y=115, w=1, h=2
# Coordonnées de la boîte la plus haute : x=323, y=117, w=3, h=3
# Coordonnées de la boîte la plus haute : x=319, y=119, w=1, h=1
# Coordonnées de la boîte la plus haute : x=310, y=125, w=1, h=3
# Coordonnées de la boîte la plus haute : x=309, y=125, w=2, h=3
# Coordonnées de la boîte la plus haute : x=306, y=128, w=2, h=2
# Coordonnées de la boîte la plus haute : x=300, y=133, w=2, h=1
# Coordonnées de la boîte la plus haute : x=297, y=136, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1066, y=0, w=19, h=8
# Coordonnées de la boîte la plus haute : x=1066, y=0, w=19, h=8
# Coordonnées de la boîte la plus haute : x=1047, y=10, w=14, h=19
# Coordonnées de la boîte la plus haute : x=1032, y=39, w=9, h=4
# Coordonnées de la boîte la plus haute : x=1008, y=63, w=20, h=29
# Coordonnées de la boîte la plus haute : x=987, y=98, w=24, h=22
# Coordonnées de la boîte la plus haute : x=966, y=130, w=16, h=13
# Coordonnées de la boîte la plus haute : x=950, y=165, w=16, h=25
# Coordonnées de la boîte la plus haute : x=264, y=176, w=2, h=2
# Coordonnées de la boîte la plus haute : x=404, y=191, w=1, h=1
# Coordonnées de la boîte la plus haute : x=249, y=201, w=3, h=3
# Coordonnées de la boîte la plus haute : x=1851, y=183, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1466, y=203, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1847, y=197, w=1, h=11
# Coordonnées de la boîte la plus haute : x=234, y=230, w=3, h=3
# Coordonnées de la boîte la plus haute : x=235, y=230, w=1, h=2
# Coordonnées de la boîte la plus haute : x=292, y=139, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1472, y=141, w=1, h=1
# Coordonnées de la boîte la plus haute : x=222, y=262, w=4, h=5
# Coordonnées de la boîte la plus haute : x=1583, y=255, w=1, h=1
# Coordonnées de la boîte la plus haute : x=218, y=271, w=6, h=4
# Coordonnées de la boîte la plus haute : x=475, y=178, w=1, h=1
# Coordonnées de la boîte la plus haute : x=214, y=289, w=2, h=5
# Coordonnées de la boîte la plus haute : x=1697, y=253, w=1, h=1
# Coordonnées de la boîte la plus haute : x=208, y=307, w=5, h=5
# Coordonnées de la boîte la plus haute : x=1758, y=149, w=1, h=1
# Coordonnées de la boîte la plus haute : x=203, y=326, w=4, h=4
# Coordonnées de la boîte la plus haute : x=201, y=335, w=5, h=6
# Coordonnées de la boîte la plus haute : x=1472, y=141, w=1, h=1
# Coordonnées de la boîte la plus haute : x=199, y=357, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1582, y=264, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1580, y=256, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1623, y=264, w=1, h=1
# Fin de la vidéo segments/segment_3.mp4 ou erreur de lecture.
# Vidéo annotée sauvegardée avec succès : segments_annotated\annotated_segment_3.mp4
# Dimensions de la vidéo segments/segment_4.mp4 : 1920x1080, FPS : 30
# Coordonnées de la boîte la plus haute : x=1768, y=151, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1595, y=307, w=2, h=1
# Coordonnées de la boîte la plus haute : x=183, y=412, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1564, y=275, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1454, y=194, w=2, h=2
# Coordonnées de la boîte la plus haute : x=630, y=394, w=5, h=6
# Coordonnées de la boîte la plus haute : x=1467, y=202, w=1, h=2
# Coordonnées de la boîte la plus haute : x=606, y=366, w=6, h=6
# Coordonnées de la boîte la plus haute : x=1475, y=240, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1584, y=229, w=1, h=2
# Coordonnées de la boîte la plus haute : x=571, y=322, w=5, h=6
# Coordonnées de la boîte la plus haute : x=571, y=322, w=5, h=6
# Coordonnées de la boîte la plus haute : x=548, y=296, w=4, h=4
# Coordonnées de la boîte la plus haute : x=1472, y=143, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1437, y=207, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1172, y=243, w=1, h=2
# Coordonnées de la boîte la plus haute : x=463, y=184, w=1, h=1
# Coordonnées de la boîte la plus haute : x=492, y=232, w=6, h=5
# Coordonnées de la boîte la plus haute : x=483, y=219, w=1, h=2
# Coordonnées de la boîte la plus haute : x=475, y=208, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1472, y=143, w=1, h=1
# Coordonnées de la boîte la plus haute : x=450, y=183, w=4, h=3
# Coordonnées de la boîte la plus haute : x=440, y=173, w=1, h=3
# Coordonnées de la boîte la plus haute : x=428, y=162, w=5, h=6
# Coordonnées de la boîte la plus haute : x=417, y=153, w=6, h=5
# Coordonnées de la boîte la plus haute : x=408, y=144, w=4, h=4
# Coordonnées de la boîte la plus haute : x=397, y=134, w=5, h=3
# Coordonnées de la boîte la plus haute : x=387, y=122, w=4, h=7
# Coordonnées de la boîte la plus haute : x=374, y=114, w=6, h=5
# Coordonnées de la boîte la plus haute : x=366, y=104, w=5, h=8
# Coordonnées de la boîte la plus haute : x=354, y=97, w=6, h=5
# Coordonnées de la boîte la plus haute : x=343, y=88, w=3, h=2
# Coordonnées de la boîte la plus haute : x=334, y=81, w=4, h=6
# Coordonnées de la boîte la plus haute : x=321, y=74, w=7, h=5
# Coordonnées de la boîte la plus haute : x=314, y=67, w=3, h=5
# Coordonnées de la boîte la plus haute : x=300, y=61, w=8, h=4
# Coordonnées de la boîte la plus haute : x=291, y=52, w=3, h=4
# Coordonnées de la boîte la plus haute : x=280, y=48, w=6, h=6
# Coordonnées de la boîte la plus haute : x=271, y=43, w=1, h=1
# Coordonnées de la boîte la plus haute : x=262, y=39, w=4, h=5
# Coordonnées de la boîte la plus haute : x=251, y=36, w=3, h=3
# Coordonnées de la boîte la plus haute : x=240, y=31, w=5, h=5
# Coordonnées de la boîte la plus haute : x=228, y=26, w=6, h=6
# Coordonnées de la boîte la plus haute : x=218, y=23, w=2, h=2
# Coordonnées de la boîte la plus haute : x=210, y=22, w=6, h=3
# Coordonnées de la boîte la plus haute : x=199, y=19, w=4, h=5
# Coordonnées de la boîte la plus haute : x=189, y=15, w=4, h=7
# Coordonnées de la boîte la plus haute : x=189, y=14, w=5, h=8
# Coordonnées de la boîte la plus haute : x=170, y=15, w=3, h=4
# Coordonnées de la boîte la plus haute : x=169, y=15, w=4, h=5
# Coordonnées de la boîte la plus haute : x=159, y=15, w=4, h=5
# Coordonnées de la boîte la plus haute : x=674, y=424, w=1, h=5
# Coordonnées de la boîte la plus haute : x=128, y=15, w=1, h=1
# Coordonnées de la boîte la plus haute : x=130, y=19, w=2, h=2
# Coordonnées de la boîte la plus haute : x=109, y=19, w=1, h=1
# Coordonnées de la boîte la plus haute : x=109, y=19, w=1, h=1
# Coordonnées de la boîte la plus haute : x=99, y=24, w=2, h=3
# Coordonnées de la boîte la plus haute : x=88, y=28, w=4, h=2
# Coordonnées de la boîte la plus haute : x=78, y=32, w=4, h=2
# Coordonnées de la boîte la plus haute : x=67, y=36, w=4, h=2
# Coordonnées de la boîte la plus haute : x=56, y=37, w=1, h=4
# Coordonnées de la boîte la plus haute : x=46, y=43, w=6, h=5
# Coordonnées de la boîte la plus haute : x=39, y=51, w=3, h=3
# Coordonnées de la boîte la plus haute : x=28, y=57, w=7, h=3
# Coordonnées de la boîte la plus haute : x=19, y=64, w=3, h=4
# Coordonnées de la boîte la plus haute : x=9, y=70, w=5, h=4
# Coordonnées de la boîte la plus haute : x=0, y=78, w=4, h=5
# Coordonnées de la boîte la plus haute : x=816, y=339, w=1, h=1
# Coordonnées de la boîte la plus haute : x=661, y=428, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1594, y=288, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1893, y=249, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1559, y=288, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1165, y=243, w=3, h=2
# Coordonnées de la boîte la plus haute : x=1828, y=296, w=1, h=1
# Coordonnées de la boîte la plus haute : x=47, y=396, w=1, h=3
# Coordonnées de la boîte la plus haute : x=176, y=360, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1168, y=242, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1444, y=240, w=2, h=1
# Coordonnées de la boîte la plus haute : x=607, y=426, w=10, h=6
# Coordonnées de la boîte la plus haute : x=47, y=400, w=1, h=1
# Coordonnées de la boîte la plus haute : x=618, y=426, w=11, h=6
# Coordonnées de la boîte la plus haute : x=181, y=375, w=1, h=1
# Coordonnées de la boîte la plus haute : x=628, y=426, w=12, h=6
# Coordonnées de la boîte la plus haute : x=1592, y=312, w=2, h=3
# Coordonnées de la boîte la plus haute : x=1893, y=249, w=3, h=1
# Coordonnées de la boîte la plus haute : x=1607, y=222, w=1, h=2
# Coordonnées de la boîte la plus haute : x=564, y=426, w=1, h=3
# Coordonnées de la boîte la plus haute : x=650, y=432, w=5, h=8
# Coordonnées de la boîte la plus haute : x=1168, y=240, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=141, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1446, y=339, w=10, h=2
# Coordonnées de la boîte la plus haute : x=665, y=426, w=2, h=3
# Coordonnées de la boîte la plus haute : x=1514, y=417, w=14, h=13
# Coordonnées de la boîte la plus haute : x=1525, y=402, w=11, h=5
# Coordonnées de la boîte la plus haute : x=1537, y=391, w=4, h=3
# Coordonnées de la boîte la plus haute : x=1472, y=142, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1544, y=372, w=22, h=18
# Coordonnées de la boîte la plus haute : x=1552, y=364, w=22, h=22
# Coordonnées de la boîte la plus haute : x=1573, y=358, w=8, h=11
# Coordonnées de la boîte la plus haute : x=1169, y=240, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1578, y=345, w=18, h=20
# Coordonnées de la boîte la plus haute : x=1592, y=342, w=8, h=3
# Coordonnées de la boîte la plus haute : x=1616, y=266, w=2, h=3
# Coordonnées de la boîte la plus haute : x=1511, y=226, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1603, y=333, w=17, h=15
# Coordonnées de la boîte la plus haute : x=1583, y=231, w=1, h=3
# Coordonnées de la boîte la plus haute : x=1616, y=331, w=15, h=14
# Coordonnées de la boîte la plus haute : x=1560, y=288, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1624, y=260, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1557, y=225, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1578, y=255, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1616, y=263, w=2, h=1
# Coordonnées de la boîte la plus haute : x=1511, y=224, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1583, y=224, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1096, y=226, w=9, h=8
# Coordonnées de la boîte la plus haute : x=1083, y=213, w=9, h=9
# Coordonnées de la boîte la plus haute : x=1070, y=196, w=4, h=2
# Coordonnées de la boîte la plus haute : x=464, y=95, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1038, y=171, w=10, h=10
# Coordonnées de la boîte la plus haute : x=1023, y=155, w=9, h=15
# Coordonnées de la boîte la plus haute : x=1006, y=144, w=5, h=6
# Coordonnées de la boîte la plus haute : x=986, y=132, w=13, h=11
# Coordonnées de la boîte la plus haute : x=973, y=120, w=2, h=4
# Coordonnées de la boîte la plus haute : x=952, y=105, w=7, h=12
# Coordonnées de la boîte la plus haute : x=934, y=96, w=10, h=12
# Coordonnées de la boîte la plus haute : x=915, y=84, w=11, h=16
# Coordonnées de la boîte la plus haute : x=894, y=74, w=12, h=18
# Coordonnées de la boîte la plus haute : x=873, y=66, w=13, h=14
# Coordonnées de la boîte la plus haute : x=853, y=57, w=13, h=15
# Coordonnées de la boîte la plus haute : x=831, y=48, w=9, h=13
# Coordonnées de la boîte la plus haute : x=808, y=42, w=16, h=14
# Coordonnées de la boîte la plus haute : x=786, y=35, w=16, h=15
# Coordonnées de la boîte la plus haute : x=765, y=27, w=8, h=13
# Coordonnées de la boîte la plus haute : x=741, y=24, w=10, h=9
# Coordonnées de la boîte la plus haute : x=719, y=21, w=12, h=15
# Coordonnées de la boîte la plus haute : x=698, y=13, w=2, h=2
# Coordonnées de la boîte la plus haute : x=666, y=12, w=13, h=11
# Coordonnées de la boîte la plus haute : x=666, y=12, w=13, h=11
# Coordonnées de la boîte la plus haute : x=619, y=10, w=6, h=8
# Coordonnées de la boîte la plus haute : x=619, y=11, w=6, h=8
# Coordonnées de la boîte la plus haute : x=588, y=13, w=12, h=12
# Coordonnées de la boîte la plus haute : x=535, y=15, w=13, h=23
# Coordonnées de la boîte la plus haute : x=535, y=15, w=13, h=23
# Coordonnées de la boîte la plus haute : x=503, y=21, w=9, h=13
# Coordonnées de la boîte la plus haute : x=480, y=28, w=3, h=2
# Coordonnées de la boîte la plus haute : x=447, y=32, w=3, h=2
# Coordonnées de la boîte la plus haute : x=411, y=45, w=8, h=12
# Coordonnées de la boîte la plus haute : x=382, y=56, w=7, h=4
# Coordonnées de la boîte la plus haute : x=352, y=64, w=2, h=3
# Coordonnées de la boîte la plus haute : x=312, y=80, w=13, h=13
# Coordonnées de la boîte la plus haute : x=287, y=96, w=1, h=1
# Coordonnées de la boîte la plus haute : x=245, y=110, w=18, h=28
# Coordonnées de la boîte la plus haute : x=204, y=134, w=25, h=23
# Coordonnées de la boîte la plus haute : x=167, y=156, w=25, h=21
# Coordonnées de la boîte la plus haute : x=136, y=176, w=2, h=1
# Coordonnées de la boîte la plus haute : x=90, y=204, w=15, h=15
# Coordonnées de la boîte la plus haute : x=49, y=237, w=11, h=6
# Coordonnées de la boîte la plus haute : x=1580, y=231, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1622, y=264, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1509, y=213, w=3, h=2
# Coordonnées de la boîte la plus haute : x=169, y=374, w=2, h=2
# Coordonnées de la boîte la plus haute : x=162, y=397, w=2, h=2
# Coordonnées de la boîte la plus haute : x=37, y=418, w=2, h=2
# Coordonnées de la boîte la plus haute : x=156, y=406, w=1, h=2
# Coordonnées de la boîte la plus haute : x=704, y=426, w=1, h=3
# Coordonnées de la boîte la plus haute : x=168, y=372, w=1, h=6
# Coordonnées de la boîte la plus haute : x=171, y=373, w=2, h=4
# Coordonnées de la boîte la plus haute : x=172, y=373, w=1, h=2
# Coordonnées de la boîte la plus haute : x=169, y=376, w=6, h=2
# Coordonnées de la boîte la plus haute : x=1557, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1472, y=141, w=2, h=2
# Coordonnées de la boîte la plus haute : x=176, y=377, w=1, h=1
# Coordonnées de la boîte la plus haute : x=464, y=95, w=1, h=1
# Coordonnées de la boîte la plus haute : x=178, y=406, w=1, h=1
# Coordonnées de la boîte la plus haute : x=165, y=364, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1559, y=312, w=1, h=1
# Coordonnées de la boîte la plus haute : x=518, y=440, w=6, h=19
# Coordonnées de la boîte la plus haute : x=162, y=431, w=4, h=2
# Coordonnées de la boîte la plus haute : x=1608, y=214, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1446, y=223, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1623, y=263, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1619, y=256, w=1, h=1
# Coordonnées de la boîte la plus haute : x=159, y=420, w=3, h=6
# Coordonnées de la boîte la plus haute : x=178, y=393, w=2, h=2
# Coordonnées de la boîte la plus haute : x=159, y=425, w=1, h=2
# Coordonnées de la boîte la plus haute : x=179, y=406, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1472, y=142, w=2, h=2
# Coordonnées de la boîte la plus haute : x=167, y=400, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1581, y=221, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1608, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1535, y=264, w=1, h=1
# Coordonnées de la boîte la plus haute : x=1512, y=215, w=1, h=1
# Coordonnées de la boîte la plus haute : x=160, y=423, w=2, h=2
# Coordonnées de la boîte la plus haute : x=159, y=380, w=1, h=1
# Coordonnées de la boîte la plus haute : x=176, y=408, w=1, h=1
# Coordonnées de la boîte la plus haute : x=167, y=415, w=1, h=1
# Coordonnées de la boîte la plus haute : x=161, y=422, w=2, h=2
# Coordonnées de la boîte la plus haute : x=1653, y=214, w=1, h=2
# Coordonnées de la boîte la plus haute : x=1607, y=247, w=1, h=1
# Fin de la vidéo segments/segment_4.mp4 ou erreur de lecture.
# Vidéo annotée sauvegardée avec succès : segments_annotated\annotated_segment_4.mp4
# Traitement terminé pour toutes les vidéos.

# %%
import cv2
import os
from tkinter import Tk, messagebox

# Variables globales
penalty_positions = []  # Liste pour stocker les positions et frames des pénalités
frame_index = 0  # Indice de la frame actuelle
global frame  # Déclarer `frame` comme variable globale pour pouvoir la modifier dans `click_event`

frame = None  # Variable pour stocker la frame actuelle
lines = []

# Fonction de gestion des clics
def click_event(event, x, y, flags, param):
    """
    Fonction pour gérer les clics de souris.
    """
    global penalty_positions, frame_index, frame
    if event == cv2.EVENT_LBUTTONDOWN:  # Clic gauche
        penalty_positions.append((frame_index, (x, y)))  # Ajouter la frame et la position du clic
        print(f"Pénalité détectée à la frame {frame_index}, position : x={x}, y={y}")
        # Dessiner un point rouge sur la frame actuelle
        cv2.circle(frame, (x, y), 5, (0, 0, 255), -1)  # Dessiner un point rouge

# Charger les segments vidéo
segment_folder = "segments"
segment_files = sorted([f for f in os.listdir(segment_folder) if f.endswith('.mp4')])

# Lire ou créer le fichier penalty_positions.txt
positions_file = 'penalty_positions.txt'
if not os.path.exists(positions_file):
    # Si le fichier n'existe pas, on le crée
    open(positions_file, 'w').close()

# Fonction pour poser la question et obtenir la réponse
def ask_question(segment_index):
    root = Tk()
    root.withdraw()  # Cacher la fenêtre principale de Tkinter

    response = messagebox.askquestion(
        "Question",
        f"La balle est-elle rentrée pour le segment {segment_index + 1} ?",
        icon='question'
    )
    root.destroy()  # Détruire la fenêtre après avoir obtenu la réponse
    return "Oui" if response == "yes" else "Non"

# Processus pour chaque segment
for index, segment_file in enumerate(segment_files):
    # Charger le segment vidéo
    segment_path = os.path.join(segment_folder, segment_file)
    cap = cv2.VideoCapture(segment_path)

    if not cap.isOpened():
        print(f"Erreur: Impossible de lire le segment {segment_file}")
        continue

    # Obtenir les dimensions et le FPS de la vidéo
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = cap.get(cv2.CAP_PROP_FPS)
    delay = int(700 / fps)  # Délai en millisecondes pour chaque frame

    # Redimensionner la fenêtre pour correspondre à la taille de la vidéo
    cv2.namedWindow("Segment", cv2.WINDOW_NORMAL)
    cv2.resizeWindow("Segment", width, height)

    # Lire et afficher le segment à la vitesse correcte
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        frame_index = int(cap.get(cv2.CAP_PROP_POS_FRAMES))  # Récupérer l'index de la frame actuelle
        cv2.imshow("Segment", frame)

        cv2.setMouseCallback("Segment", click_event)  # Associer la gestion des clics

        if cv2.waitKey(delay) & 0xFF == ord('q'):  # Respecter la vitesse de la vidéo
            break

    cap.release()

    # Demander la réponse après avoir visionné la vidéo
    reponse = ask_question(index)

    # Ajouter les positions de pénalités et les réponses à la liste
    for frame_num, position in penalty_positions:
        lines.append(f"Video: {segment_file}, Frame: {frame_num}, Position: {position}, Rentree : {reponse}\n")

    # Réinitialiser la liste des positions après chaque segment
    penalty_positions.clear()

    # Fermer toutes les fenêtres après avoir visionné chaque segment
    cv2.destroyAllWindows()

# Écrire les lignes mises à jour dans le fichier
with open(positions_file, 'w') as file:
    file.writelines(lines)

print("Mises à jour enregistrées dans penalty_positions.txt.")
# Out:
# Pénalité détectée à la frame 240, position : x=840, y=550
# Pénalité détectée à la frame 240, position : x=1231, y=530
# Pénalité détectée à la frame 88, position : x=1613, y=509
# Pénalité détectée à la frame 111, position : x=1608, y=509
# Pénalité détectée à la frame 63, position : x=1327, y=539
# Mises à jour enregistrées dans penalty_positions.txt.

# %%
import cv2
import os
import re

# Dossier contenant les segments vidéo
video_folder = "segments"
frame_output_folder = "frames_output"

# Créer le dossier de sortie pour les frames extraites
os.makedirs(frame_output_folder, exist_ok=True)

# Fonction pour extraire une frame spécifique d'une vidéo et la sauvegarder
def extract_and_save_frame(video_path, frame_number, output_folder):
    video = cv2.VideoCapture(video_path)
    video.set(cv2.CAP_PROP_POS_FRAMES, frame_number - 1)  # Les frames commencent à 0
    success, current_frame = video.read()
    if success:
        frame_output_path = os.path.join(output_folder, f"frame_{frame_number}_{os.path.basename(video_path).replace('.mp4', '')}.png")
        cv2.imwrite(frame_output_path, current_frame)
        print(f"Frame numéro {frame_number} extraite et sauvegardée sous {frame_output_path}")
    else:
        print(f"Erreur : impossible d'extraire la frame numéro {frame_number}.")
    video.release()

# Lecture et analyse du fichier texte
input_path = 'penalty_positions.txt'
with open(input_path, 'r') as file:
    lines = file.readlines()

pattern = r"Video: (.*?), Frame: (\d+), Position: \((\d+), (\d+)\), Rentree : (Oui|Non)"
penalty_positions = []
for line in lines:
    match = re.search(pattern, line)
    if match:
        video_name = match.group(1)
        frame_number = int(match.group(2))
        position = (int(match.group(3)), int(match.group(4)))
        video_path = os.path.join(video_folder, video_name)
        penalty_positions.append((video_path, frame_number, position))

# Extraction et sauvegarde des frames
for video_path, frame_number, position in penalty_positions:
    extract_and_save_frame(video_path, frame_number, frame_output_folder)
# Out:
# Frame numéro 240 extraite et sauvegardée sous frames_output\frame_240_segment_1.png
# Frame numéro 240 extraite et sauvegardée sous frames_output\frame_240_segment_1.png
# Frame numéro 88 extraite et sauvegardée sous frames_output\frame_88_segment_3.png
# Frame numéro 111 extraite et sauvegardée sous frames_output\frame_111_segment_3.png
# Frame numéro 63 extraite et sauvegardée sous frames_output\frame_63_segment_4.png

# %%
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt
# Charger les modèles entraînés
model_poteaux = YOLO("modèle_poteau_50.pt")
model_terrain = YOLO("model_terrain_60.pt")

# %%
import os
import cv2
import numpy as np
import re

# Chemin du dossier contenant les images
image_folder = "frames_output"

# Récupérer tous les fichiers image dans le dossier
image_paths = [os.path.join(image_folder, f) for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

# Liste pour stocker toutes les coordonnées transformées
all_transformed_coords = []

# Traitement de chaque image
for image_path in image_paths:

    print(image_path)

    # Expression régulière pour capturer les numéros après "frame_" et "segment_" dans le nom du fichier
    match = re.search(r"frame_(\d+)_segment_(\d+)", image_path)

    if match:
        frame_number = int(match.group(1))  # Récupère le numéro de la frame
        video_number = int(match.group(2))  # Récupère le numéro de la vidéo
        print("Numéro de la frame :", frame_number)
        print("Numéro de la vidéo :", video_number)


    else:
        print("Aucun numéro de frame trouvé dans le nom du fichier.")
        # Charger l'image
    image = cv2.imread(image_path)

    # Exécuter les modèles sur l'image
    results_poteaux = model_poteaux(image)
    results_terrain = model_terrain(image)

    # Seuil de confiance minimum
    confidence_threshold = 0.7

    # Récupérer les keypoints validés du modèle "Poteaux"
    filtered_keypoints_poteaux = []
    for instance_idx, keypoints in enumerate(results_poteaux[0].keypoints.data):
        for keypoint_idx, (x, y, conf) in enumerate(keypoints):
            if conf.item() >= confidence_threshold:
                if keypoint_idx + 1 == 5: 
                    filtered_keypoints_poteaux.append({
                        "keypoint": "p_droit",
                        "x": x.item(),
                        "y": y.item()
                    })
                elif keypoint_idx + 1 == 6: 
                    filtered_keypoints_poteaux.append({
                        "keypoint": "p_gauche",
                        "x": x.item(),
                        "y": y.item()
                    })

    # Récupérer et renommer les keypoints validés du modèle "Terrain"
    filtered_keypoints_terrain = []
    for keypoint_idx, keypoints in enumerate(results_terrain[0].keypoints.data):
        for kp_idx, (x, y, conf) in enumerate(keypoints):
            if conf.item() >= confidence_threshold:
                if kp_idx + 1 in [5]:
                    keypoint_name = ""
                elif kp_idx + 1 in [6]: 
                    keypoint_name = "15_32"
                elif kp_idx + 1 in [7]: 
                    keypoint_name = "55_32"
                elif kp_idx + 1 in [8]: 
                    keypoint_name = "65_32"
                elif kp_idx + 1 in [9]: 
                    keypoint_name = "15_50"
                elif kp_idx + 1 in [10]:  
                    keypoint_name = "55_50"
                elif kp_idx + 1 in [11]:
                    keypoint_name = "65_50"
                elif kp_idx + 1 in [12]:
                    keypoint_name = "5_50"
                else:
                    keypoint_name = f"T{kp_idx + 1}_autre"

                filtered_keypoints_terrain.append({
                    "keypoint_name": keypoint_name,
                    "x": x.item(),
                    "y": y.item()
                })

    # Charger les coordonnées depuis le fichier .txt
    coordinates = []

    with open('penalty_positions.txt', 'r') as file:
        for line in file:
            print(line)
            # Vérifier si la ligne contient le numéro de la vidéo et de la frame en cours
            if f"Video: segment_{video_number}.mp4, Frame: {frame_number}" in line:  # Cherche la ligne contenant "Video: segment_X.mp4, Frame: Y"
                # Extraire les coordonnées après "Position:"
                print(video_number)
                print(frame_number)
                if "Position" in line:
                    parts = line.strip().split("Position:")[1].strip()
                    coordinates_str = parts.split(")")[0]  # Enlever tout après la parenthèse fermante
                    x, y = map(int, coordinates_str.strip("()").split(", "))  # Extraire les coordonnées
                    coordinates.append([x, y])
                    print("coordinates", coordinates)



    # Vérification des coordonnées
    if not coordinates:
        print(f"Erreur : aucune coordonnée trouvée dans le fichier .txt pour {image_path}.")
        continue

    # Extraire les points des poteaux et du terrain
    p_droit = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_poteaux if d["keypoint"] == "p_droit"), (0, 0))
    p_gauche = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_poteaux if d["keypoint"] == "p_gauche"), (0, 0))
    p_15_32 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "15_32"), (0, 0))
    p_55_32 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "55_32"), (0, 0))
    p_65_32 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "65_32"), (0, 0))
    p_15_50 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "15_50"), (0, 0))
    p_55_50 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "55_50"), (0, 0))
    p_65_50 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "65_50"), (0, 0))
    p_5_50 = next(((int(d["x"]), int(d["y"])) for d in filtered_keypoints_terrain if d["keypoint_name"] == "5_50"), (0, 0))

    # Déterminer les points d'image et réels
    if p_65_50 == (0, 0):
        image_points = np.array([p_5_50, p_15_50, p_15_32, p_gauche], dtype=np.float32)
        real_points_test = np.array([[5, 50], [15, 50], [15, 32], [32.2, 10]], dtype=np.float32)
    if p_5_50 == (0, 0):
        image_points = np.array([p_55_50, p_65_50, p_65_32, p_55_32], dtype=np.float32)
        real_points_test = np.array([[55, 50], [65, 50], [65, 32], [55, 32]], dtype=np.float32)
    if p_5_50 == (0, 0) and p_65_32 == (0,0):
        image_points = np.array([p_15_32, p_15_50, p_55_50, p_55_32], dtype=np.float32)
        real_points_test = np.array([[15, 32], [15, 50], [55, 50], [55, 32]], dtype=np.float32)

    # Calcul de la matrice d'homographie
    H, _ = cv2.findHomography(image_points, real_points_test)

    # Convertir les coordonnées des joueurs
    player_coords = np.array(coordinates, dtype=np.float32)
    player_coords_transformed = cv2.perspectiveTransform(np.array([player_coords]), H)

    # Extraire les coordonnées transformées
    transformed_coords = player_coords_transformed[0]

    all_transformed_coords.append(transformed_coords)

    # Affichage des coordonnées transformées pour l'image
    print(f"Coordonnées des ballons transformées pour {image_path} (en mètres) :")
    for coord in transformed_coords:
        print(f"Joueur : {coord}")

# Afficher toutes les coordonnées transformées
print("Toutes les coordonnées transformées (en mètres) :")
for coords in all_transformed_coords:
    for coord in coords:
        print(f"Joueur : {coord}")

print(all_transformed_coords)
# Out:
# frames_output\frame_111_segment_1.png
# Numéro de la frame : 111
# Numéro de la vidéo : 1
#
# 0: 384x640 1 poteaux, 1665.2ms
# Speed: 12.1ms preprocess, 1665.2ms inference, 15.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1048.3ms
# Speed: 8.2ms preprocess, 1048.3ms inference, 11.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Erreur : aucune coordonnée trouvée dans le fichier .txt pour frames_output\frame_111_segment_1.png.
# frames_output\frame_111_segment_3.png
# Numéro de la frame : 111
# Numéro de la vidéo : 3
#
# 0: 384x640 1 poteaux, 953.6ms
# Speed: 7.7ms preprocess, 953.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1282.3ms
# Speed: 3.6ms preprocess, 1282.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# 3
# 111
# coordinates [[1608, 509]]
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Coordonnées des ballons transformées pour frames_output\frame_111_segment_3.png (en mètres) :
# Joueur : [     66.334       36.14]
# frames_output\frame_117_segment_2.png
# Numéro de la frame : 117
# Numéro de la vidéo : 2
#
# 0: 384x640 1 poteaux, 1177.2ms
# Speed: 9.2ms preprocess, 1177.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1055.6ms
# Speed: 8.2ms preprocess, 1055.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Erreur : aucune coordonnée trouvée dans le fichier .txt pour frames_output\frame_117_segment_2.png.
# frames_output\frame_240_segment_1.png
# Numéro de la frame : 240
# Numéro de la vidéo : 1
#
# 0: 384x640 1 poteaux, 923.2ms
# Speed: 0.0ms preprocess, 923.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1120.3ms
# Speed: 5.0ms preprocess, 1120.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# 1
# 240
# coordinates [[840, 550]]
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# 1
# 240
# coordinates [[840, 550], [1231, 530]]
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Coordonnées des ballons transformées pour frames_output\frame_240_segment_1.png (en mètres) :
# Joueur : [     38.931      36.873]
# Joueur : [     53.155      36.397]
# frames_output\frame_51_segment_3.png
# Numéro de la frame : 51
# Numéro de la vidéo : 3
#
# 0: 384x640 1 poteaux, 1390.9ms
# Speed: 0.0ms preprocess, 1390.9ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1009.3ms
# Speed: 3.9ms preprocess, 1009.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Erreur : aucune coordonnée trouvée dans le fichier .txt pour frames_output\frame_51_segment_3.png.
# frames_output\frame_63_segment_4.png
# Numéro de la frame : 63
# Numéro de la vidéo : 4
#
# 0: 384x640 1 poteaux, 1103.3ms
# Speed: 0.0ms preprocess, 1103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1067.1ms
# Speed: 0.0ms preprocess, 1067.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# 4
# 63
# coordinates [[1327, 539]]
# Coordonnées des ballons transformées pour frames_output\frame_63_segment_4.png (en mètres) :
# Joueur : [     55.603      34.318]
# frames_output\frame_87_segment_4.png
# Numéro de la frame : 87
# Numéro de la vidéo : 4
#
# 0: 384x640 1 poteaux, 922.7ms
# Speed: 0.0ms preprocess, 922.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 1106.7ms
# Speed: 10.7ms preprocess, 1106.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Erreur : aucune coordonnée trouvée dans le fichier .txt pour frames_output\frame_87_segment_4.png.
# frames_output\frame_88_segment_3.png
# Numéro de la frame : 88
# Numéro de la vidéo : 3
#
# 0: 384x640 1 poteaux, 907.6ms
# Speed: 10.0ms preprocess, 907.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 Terrain, 960.8ms
# Speed: 0.0ms preprocess, 960.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Video: segment_1.mp4, Frame: 240, Position: (840, 550), Rentree : Non
#
# Video: segment_1.mp4, Frame: 240, Position: (1231, 530), Rentree : Non
#
# Video: segment_3.mp4, Frame: 88, Position: (1613, 509), Rentree : Non
#
# 3
# 88
# coordinates [[1613, 509]]
# Video: segment_3.mp4, Frame: 111, Position: (1608, 509), Rentree : Non
#
# Video: segment_4.mp4, Frame: 63, Position: (1327, 539), Rentree : Non
#
# Coordonnées des ballons transformées pour frames_output\frame_88_segment_3.png (en mètres) :
# Joueur : [     66.583      36.203]
# Toutes les coordonnées transformées (en mètres) :
# Joueur : [     66.334       36.14]
# Joueur : [     38.931      36.873]
# Joueur : [     53.155      36.397]
# Joueur : [     55.603      34.318]
# Joueur : [     66.583      36.203]
# [array([[     66.334,       36.14]], dtype=float32), array([[     38.931,      36.873],
#        [     53.155,      36.397]], dtype=float32), array([[     55.603,      34.318]], dtype=float32), array([[     66.583,      36.203]], dtype=float32)]

# %%
import matplotlib.pyplot as plt
import numpy as np

# # Affichage des coordonnées transformées
# print("Toutes les coordonnées transformées (en mètres) :")
# for coords in all_transformed_coords:
#     print(f"Joueur : {coords[0][0]}, {coords[0][1]}")  # Affichage des coordonnées x et y

# Création du terrain de rugby
plt.figure(figsize=(12, 7))
plt.title("Visualisation des positions des ballons sur le terrain de rugby")

# Dimensions du terrain en mètres
terrain_width = 70
terrain_length = 70
terrain_playable_length = 60

# Tracer les bandes alternées verticales (vert clair et vert foncé)
for i in range(0, terrain_width, 5):
    color = 'darkgreen' if (i // 5) % 2 == 0 else 'green'
    plt.fill_betweenx([0, terrain_length], i, i + 5, color=color)

# Tracer le contour du terrain
plt.plot([0, terrain_width, terrain_width, 0, 0],
         [0, 0, terrain_length, terrain_length, 0], color='white', linewidth=2)

# Tracer les lignes principales
plt.axhline(0, color='white', linestyle='-', linewidth=2)
plt.axhline(10, color='white', linestyle='-', linewidth=2)
plt.axhline(22 + 10, color='white', linestyle='--', linewidth=1)
plt.axhline(50 + 10, color='white', linestyle='-', linewidth=1)

# Tracer les croix et les lignes de terrain
cross_x_positions = [5, 15, terrain_width - 15, terrain_width - 5]
for x in cross_x_positions:
    plt.plot([x - 2.5, x + 2.5], [15, 15], color='white', linewidth=1)
    plt.plot([x, x], [15, 20], color='white', linewidth=1)
    plt.plot([x - 2, x + 2], [terrain_length - 20, terrain_length - 20], color='white', linewidth=1)
    plt.plot([x, x], [terrain_length - 22, terrain_length - 18], color='white', linewidth=1)

line_x_positions = [25, 35, 45]
for x in line_x_positions:
    plt.plot([x - 2.5, x + 2.5], [15, 15], color='white', linewidth=1)
    plt.plot([x - 2, x + 2], [terrain_length - 20, terrain_length - 20], color='white', linewidth=1)

# Extraction des coordonnées x et y de all_transformed_coords
x_coords = [coord[0][0] for coord in all_transformed_coords]  # Liste des coordonnées x
y_coords = [coord[0][1] for coord in all_transformed_coords]  # Liste des coordonnées y

# Tracer les positions des joueurs ou des points
plt.scatter(x_coords, y_coords, color='blue', label='Joueurs')

# Ajouter des labels pour les axes
plt.xlabel("Largeur du terrain (m)")
plt.ylabel("Longueur du terrain (m)")

# Ajustement du rapport d'aspect et grille discrète
plt.gca().set_aspect('equal', adjustable='box')
plt.grid(color='gray', linestyle='--', linewidth=0.3, alpha=0.3)

# Afficher la légende et la visualisation
plt.legend()
plt.show()

# %% [markdown]
# ## Environmental Impact

# %% [markdown]
# ### 1. Find the CPU consumption with Powershell and powercfg /energy

# %%
import sys
import os 

sys.path.append(os.path.abspath(os.path.join(os.path.dirname('__file__'), '..')))

import environmental_impact

# %% [markdown]
# ### 2. Take the equivalent in kgCO2

# %% [markdown]
# #### Ball Detection :

# %%
consumption_kwh = 0.0003265
environmental_impact.calculate_impact(consumption_kwh=consumption_kwh)
# Out:
# URL: https://api.electricitymap.org/v3/carbon-intensity/latest
# Headers: {'auth-token': 'mkghuvLIc24M7'}
# Data fetched successfully!
# Response JSON: {'zone': 'FR', 'carbonIntensity': 63, 'datetime': '2025-01-14T15:00:00.000Z', 'updatedAt': '2025-01-14T14:40:03.994Z', 'createdAt': '2025-01-11T15:41:18.428Z', 'emissionFactorType': 'lifecycle', 'isEstimated': True, 'estimationMethod': 'TIME_SLICER_AVERAGE'}
# Total CO2 emissions for 0.000383 kWh: 2.4129e-05 kgCO2eq

# %% [markdown]
# #### Field detection :

# %%
consumption_kwh = 0.000383
environmental_impact.calculate_impact(consumption_kwh=consumption_kwh)
# Out:
# URL: https://api.electricitymap.org/v3/carbon-intensity/latest
# Headers: {'auth-token': 'mkghuvLIc24M7'}
# Data fetched successfully!
# Response JSON: {'zone': 'FR', 'carbonIntensity': 63, 'datetime': '2025-01-14T15:00:00.000Z', 'updatedAt': '2025-01-14T14:40:03.994Z', 'createdAt': '2025-01-11T15:41:18.428Z', 'emissionFactorType': 'lifecycle', 'isEstimated': True, 'estimationMethod': 'TIME_SLICER_AVERAGE'}
# Total CO2 emissions for 0.000383 kWh: 2.4129e-05 kgCO2eq
